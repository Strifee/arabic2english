# %%
import string
import pandas as pd
import regex as re
from unicodedata import normalize
from pickle import load
from pickle import dump
from collections import Counter

# %%
# load doc into memory
def load_doc(filename):
	# open the file as read only
	file = open(filename, mode='rt', encoding='utf-8')
	# read all text
	text = file.read()
	# close the file
	file.close()
	return text

# %%
# split a loaded document into sentences
def to_sentences(doc):
	return doc.strip().split('\n')

# %%
# shortest and longest sentence lengths
def sentence_lengths(sentences):
	lengths = [len(s.split()) for s in sentences]
	return min(lengths), max(lengths)

# %%
# load doc into memory
def load_doc(filename):
	# open the file as read only
	file = open(filename, mode='rt', encoding='utf-8')
	# read all text
	text = file.read()
	# close the file
	file.close()
	return text

# split a loaded document into sentences
def to_sentences(doc):
	return doc.strip().split('\n')

# shortest and longest sentence lengths
def sentence_lengths(sentences):
	lengths = [len(s.split()) for s in sentences]
	return min(lengths), max(lengths)

# %%
# load 1st Arabic data
arabic_filename = 'data/Arab-Acquis/Arabic-Translations/test.en_ref.ar'
arabic_doc = load_doc(arabic_filename)
arabic_sentences = to_sentences(arabic_doc)
minlen1, maxlen1 = sentence_lengths(arabic_sentences)
print('Arabic data: sentences=%d, min=%d, max=%d' % (len(arabic_sentences), minlen1, maxlen1))

# load 1st English data
english_filename = 'data/Arab-Acquis/JRC-ACQUIS/ac-test.en'
english_doc = load_doc(english_filename)
english_sentences = to_sentences(english_doc)
minlen1, maxlen1 = sentence_lengths(english_sentences)
print('English data: sentences=%d, min=%d, max=%d' % (len(english_sentences), minlen1, maxlen1))
# Out:
# Arabic data: sentences=4107, min=1, max=246
# English data: sentences=4107, min=1, max=269

# %%
arabic_sentences[0]
# Out:
# 'مجلس الجماعة الاقتصادية الأوروبية'

# %%
english_sentences[0]
# Out:
# 'THE COUNCIL OF THE EUROPEAN ECONOMIC COMMUNITY,'

# %%
import pandas as pd
df1 = pd.read_csv("data/arabic_english.txt",delimiter="\t",names=["eng","ar"])
df1
# Out:
#                                                      eng  \
# 0                                                    Hi.
# 1                                                   Run!
# 2                                                  Help!
# 3                                                  Jump!
# 4                                                  Stop!
# ...                                                  ...
# 24633  rising voices promoting a more linguistically ...
# 24634  following last year s successful campaign we i...
# 24635  during last year s challenge we also met langu...
# 24636  to take part just follow the simple steps outl...
# 24637  you will also find links to some free web base...
#
#                                                       ar
# 0                                                مرحبًا.
# 1                                                  اركض!
# 2                                                النجدة!
# ...

# %%
import pandas as pd
df2 = pd.DataFrame(list(zip(english_sentences,arabic_sentences)), columns=['eng','ar'])
df2
# Out:
#                                                     eng  \
# 0       THE COUNCIL OF THE EUROPEAN ECONOMIC COMMUNITY,
# 1     Whereas the adoption of a common transport pol...
# 2                                             Article 1
# 3     3. The types of carriage listed in Annex II sh...
# 4     Member States shall inform the Commission of t...
# ...                                                 ...
# 4102  Having regard to the request made by Luxembour...
# 4103  (2) Such derogations should be granted, at the...
# 4104                                          Article 1
# 4105  (b) France is granted derogations for the prod...
# 4106  After expiry of the transitional period, Austr...
#
#                                                      ar
# 0                     مجلس الجماعة الاقتصادية الأوروبية
# 1     حيث أن اعتماد سياسة نقل مشتركة تنطوي من بين أم...
# 2                                              المادة 1
# 3     3. لا تخضع أنواع النقل المدرجة في الملحق الثان...
# ...

# %%
# load 2nd Arabic data
arabic_filename2 = 'data/Arab-Acquis/Arabic-Translations/tune.en_ref.ar'
arabic_doc2 = load_doc(arabic_filename2)
arabic_sentences2 = to_sentences(arabic_doc2)
minlen2, maxlen2 = sentence_lengths(arabic_sentences2)
print('Arabic data: sentences=%d, min=%d, max=%d' % (len(arabic_sentences), minlen2, maxlen2))

# load 2nd English data
english_filename2 = 'data/Arab-Acquis/JRC-ACQUIS/ac-dev.en'
english_doc2 = load_doc(english_filename2)
english_sentences2 = to_sentences(english_doc2)
minlen2, maxlen2 = sentence_lengths(english_sentences2)
print('English data: sentences=%d, min=%d, max=%d' % (len(english_sentences), minlen2, maxlen2))
# Out:
# Arabic data: sentences=4107, min=1, max=235
# English data: sentences=4107, min=1, max=289

# %%
import pandas as pd
df3 = pd.DataFrame(list(zip(english_sentences2,arabic_sentences2)), columns=['eng','ar'])
df3
# Out:
#                                                     eng  \
# 0     Having regard to the Treaty establishing the E...
# 1     Whereas the progressive establishment of the c...
# 2     1. Each Member State shall, by the end of 1962...
# 3     4. The two Annexes to this Directive shall for...
# 4                                             Article 3
# ...                                                 ...
# 4102                                           Whereas:
# 4103  (3) The measures provided for in this Regulati...
# 4104  1. The following derogations from the provisio...
# 4105  (c) Luxembourg is granted derogations for the ...
# 4106                                          Article 2
#
#                                                      ar
# 0     مع الأخذ في الاعتبار المعاهدة التي أنشئت بموجب...
# 1     وحيث أنه لا يجب أن تواجه عملية الإنشاء التدريج...
# 2     1. يتعيّن على كلّ دولة عضو بحلول نهاية العام 1...
# 3     4 يشكّل الملحقان المرفقان بهذا التوجيه جزءاً ل...
# ...

# %%
data = pd.concat([df1, df2], ignore_index=True)
data
# Out:
#                                                      eng  \
# 0                                                    Hi.
# 1                                                   Run!
# 2                                                  Help!
# 3                                                  Jump!
# 4                                                  Stop!
# ...                                                  ...
# 28740  Having regard to the request made by Luxembour...
# 28741  (2) Such derogations should be granted, at the...
# 28742                                          Article 1
# 28743  (b) France is granted derogations for the prod...
# 28744  After expiry of the transitional period, Austr...
#
#                                                       ar
# 0                                                مرحبًا.
# 1                                                  اركض!
# 2                                                النجدة!
# ...

# %%
final_dataset = pd.concat([data, df3], ignore_index=True)
final_dataset = final_dataset.reset_index(drop=True)

# %%
final_dataset.to_csv('data/data.txt')

# %%
df = pd.read_csv("data/data.txt")
df = df.drop(df.columns[0], axis=1)
df
# Out:
#                                                      eng  \
# 0                                                    Hi.
# 1                                                   Run!
# 2                                                  Help!
# 3                                                  Jump!
# 4                                                  Stop!
# ...                                                  ...
# 32847                                           Whereas:
# 32848  (3) The measures provided for in this Regulati...
# 32849  1. The following derogations from the provisio...
# 32850  (c) Luxembourg is granted derogations for the ...
# 32851                                          Article 2
#
#                                                       ar
# 0                                                مرحبًا.
# 1                                                  اركض!
# 2                                                النجدة!
# ...
